# %% [markdown]
# # Computer Vision: Assignment 3 Part 2 - Object Detection [60%]
#
# This notebook contains a partial minimal implementation (modelling, training and visualization code) an of a region-CNN object detector.
#
# The first steps would be to understand what anchors are. Anchors are nothing but crops of a specific size and position in the image. The job of our object detector is to classify each anchor as containing an object or not. If the anchor contains an object, we want to find out by how much our anchor needs to change in shape and position to best fit the object in it. (By how much the height, width and center x and y cordinates change.)
#
# Hence, object detection is a multi task network which does **classification** and **regression**.
#
#
# The final objective of completing this notebook is to generate some visualizations of the network running on images in the validation set.
#
# You should upload the completed notebook to NYU Classes.

# %% [markdown]
# Let's start by loading some important modules

# %%
# load important modules
# !git clone https://github.com/simonkorman/CV-Ex3-part2.git
# %cd CV-Ex3-part2
# Out:
# Cloning into 'CV-Ex3-part2'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 55 (delta 18), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (55/55), done.
# /content/CV-Ex3-part2

# %% [markdown]
# ## Dataset
#
# Let's introduce our dataset. We have a Pytorch dataloader which outputs images and the ground truth data for the bounding boxes. We visualize the dataset below. You don't need to write any code here. However, you can try to get a good understanding of the structure of the dataset.

# %%
from extras.shapes_loader import get_shapes_loader
from extras.util import *
import torch
import matplotlib.pyplot as plt
import matplotlib
import torch.nn as nn
from extras.encoder import ResnetEncoder
import torch.nn.functional as F
from extras.anchors import get_offsets
from extras.boxes import box_iou, nms
import numpy as np

use_cuda = torch.cuda.is_available()

batch_sz =  4 # batch size for training and testing

# data loading: You may (*and should*) change the dataset sizes (make sure that they are multiples of the batch size)
trainloader, valloader, _ = get_shapes_loader(batch_sz=batch_sz, train_samples=1200, val_samples=600)

device = 'cuda' 

matplotlib.rcParams['figure.figsize'] = (10.0, 10.0)

# %% [markdown]
# A visual taste of the dataset, given as sample (image) / target (labels) pairs, which consists of triangle/square/circle colored objects on a uniform background.

# %%
sample, target = iter(trainloader).next()
sample = torch.stack(sample,dim=0)
visDet(sample, target)

# %% [markdown]
# ### Target Data for the Dataset
#
# The targets of the dataset have 2 types of information for each image.
#
# 1. The **bounding boxes** which is a tensor of size (N x 4).
# here is N is the number of objects in the image and 4 correspond to:
#
#     a. top left x coordinate
#     b. top left y coordinate
#     c. bottom right x coordinate
#     d. bottom right y coordinate
#
# 2. The **classification labels** of size Nx1. Here the 1 corresponds to the label of the object (whether it is a triangle, square or circle). We will basically ignore the label in this excercise (i.e. treat all objects as one class).

# %%
print(target[0])
# Out:
# {'bounding_box': tensor([[ 29,  59,  91, 121],
#         [ 29,  14,  81,  66]]), 'labels': tensor([2, 1], dtype=torch.int32)}

# %% [markdown]
# ### Creating a fixed collection of "chunks" or "anchors" for our image.
#
# Our image is 128 x 128 in size and we will use a stride of 16, with 3 anchor sizes at each position, of dimensions 40x40, 50x50 and 60x60. We should get 192 anchors (since 128/16 = 8 and 8x8x3 = 192).
#
# Hence, our neural network should output a feature map of 8 x 8 in spatial dimensions. Each grid point in this feature map is an anchor position, with 3 candidate anchors.
#
# Your first ***task*** [**10%**] is to write the code that creates these 192 anchors with respect to an image size of 128x128. Each anchor is represented by the top left and bottom right x,y coordinates of the anchors (in this order) with respect to the pixel coordinates of a 128x128 image.
#
# Hence, the output of the below function should be a numpy array of size [192,4]. Make sure to think about the correct order of collecting these 192 anchors. They should be in coordination with the output of the network that we will see next.

# %%
def get_anchor_boxes():
    """
    Generate 192 boxes where each box is represented by :
    [top_left_x, top_left_y, bottom_right_x, bottom_right_y]

    Each anchor position should generate 3 boxes according to the scales and ratios given.

    Return this result as a numpy array of size [192,4]
    """
    stride = 16 # The stride of the final feature map is 16 (the model compresses the image from 128 x 128 to 8 x 8)
    map_sz = 128 # this is the length of height/width of the image

    anchor_boxes = torch.zeros([192, 4])
    # anchor_boxes[i, 0] == top_left_x
    # anchor_boxes[i, 1] == top_left_y
    # anchor_boxes[i, 2] == bottom_right_x
    # anchor_boxes[i, 3] == bottom_right_y
    strides = np.arange(0, map_sz, stride)

    k = 0
    
    for i in zip(strides):
      for j in zip(strides):
        dim = 40
        while dim < 61:
          anchor_boxes[k, 0] = j[0]
          anchor_boxes[k, 1] = i[0]
          anchor_boxes[k, 2] = dim + j[0]
          anchor_boxes[k, 3] = dim + i[0]
          dim += 10
          k += 1
    return anchor_boxes

# retrieve the anchors
anchor_boxes = get_anchor_boxes()
assert anchor_boxes.shape == (192,4)

# %% [markdown]
# ### Model
#
# We will use the 3rd output feature from the resnet18 encoder, which represents a stride of 16. Given a 128x128 image, it will result in a map of size 8 x 8, with depth of 256. On this feature map we applay an additional standard 3x3 convolutional layer (+relu activation) that will leave us again with a 8x8x256 intermediate feature embedding.
#
# Recall that we wish to make predictions per anchor. We associate each of the 8x8 spatial dimensions with those of the respecive anchors. Therefore, for each spatial location we will add two output heads, which will predict the object existence and required bounding-box location update. These are implemented by operating on the entire volume at once, using 2 separate simple 1x1 convolutions with the respective output dimensions.
#
# Our model is defined by the class 'ShapesModel', where the 'forward' function defines the forward pass of the network.

# %% [markdown]
# ### Illustration of the suggested architecture
# ![diagram_70.png](data:image/png;base64,...)

# %%
class ShapesModel(nn.Module):

    def __init__(self):
        super(ShapesModel, self).__init__()

        # for each grid in the feature map we have 3 anchors of sizes: 40x40, 50x50, 60x60
        num_anchors = 3

        # regular resnet 34 encoder
        self.encoder = ResnetEncoder(num_layers=34, pretrained=False)

        # a small conv net
        self.conv = nn.Conv2d(
            256, 256, kernel_size=3, stride=1, padding=1
        )
        self.bn1 = nn.BatchNorm2d(256)

        # This is a head that predicts whether a chunk/anchor contains an object or not.
        self.cls_logits = nn.Conv2d(256, 3*1, kernel_size=1)
        self.bn2 = nn.BatchNorm2d(3)

        # This is a head that regresses over the 4 bounding box offsets for each anchor
        self.bbox_pred = nn.Conv2d(256, 3*4, kernel_size=1)
        self.bn3 = nn.BatchNorm2d(12)

    def permute_and_flatten(self, layer, N, A, C, H, W):
        # helper function that rearranges the input for the loss function
        layer = layer.view(N, -1, C, H, W)
        layer = layer.permute(0, 3, 4, 1, 2)
        layer = layer.reshape(N, -1, C)
        return layer
    
    def reshape_regressions(self, cls_pred, box_pred):
        # helper function that gets outputs in the right shape for applying the loss
        # A = number of anchors (3)
        # C is 1
        N, AxC, H, W = cls_pred.shape
        Ax4 = box_pred.shape[1]
        A = Ax4 // 4
        C = AxC // A
        cls_pred = self.permute_and_flatten(cls_pred, N, A, C, H, W)
        
        box_pred = self.permute_and_flatten(box_pred, N, A, 4, H, W)
        return cls_pred, box_pred

    def forward(self, x):
        bt_sz = x.size(0)

        # we take the 3rd output feature map of size 8 x 8 from
        # the resnet18 encoder this means that the stride
        # is 16 as our input image is 128x128 in size.
        x = self.encoder(x)[3]

        # next pass it through a convolutional layer
        x = F.relu(self.conv(x))

        # finally make the predictions
        cls_pred = torch.sigmoid(self.cls_logits(x))
        box_pred = self.bbox_pred(x)
  
        # expected output sizes of head (dimension 0 is for the batch_size)
        assert cls_pred.shape[1:] == (3, 8, 8)
        assert box_pred.shape[1:] == (12, 8, 8)
        # this is a rearragenemt of the output tensors dimensions
        cls_pred, box_pred = self.reshape_regressions(cls_pred, box_pred)

         # expected output sizes of head (dimension 0 is for the batch_size)
        assert cls_pred.shape[1:] == (192, 1)
        assert box_pred.shape[1:] == (192, 4)
        
        return cls_pred.squeeze(2), box_pred

# %% [markdown]
# Basic testing of the model on a random input

# %%
m = ShapesModel()
a = torch.randn(1,3,128,128) # dummy input
cls_pred, box_pred = m(a)
print('The outputs of the net are of size: ', cls_pred.size(), box_pred.size())

assert cls_pred.size() == (1,192) and box_pred.size() == (1,192,4)
# Out:
# The outputs of the net are of size:  torch.Size([1, 192]) torch.Size([1, 192, 4])

# %% [markdown]
# ## **Supervision:** 1. organizing the ground-truth information
#
# ***get_GT_anchors*** is a function that converts the ground-truth information to the world of our anchors. Specifically, given the collection of true object bounding-boxes, it will assign to each of our anchors the following:
#
# 1. Whether it has an object in it or not. This is done by measuring IOU (intersection-over-union) of the chunk with each of the true bounding boxes. If the (maximal found) IOU is > 0.7, we say that the chunk contains the object. If it is less than 0.3, we say the chunk only contains background. If the value is somewhere in between, we say it is a bad chunk (and will not use it's contribution to the loss function).
#
# 2. How much should the anchor change in height, width and how much should it translate to best fit the object. These offsets are 4 values, for the height, width, center x and y coordinate.
#
# Your second ***task*** [**10%**] is to calculate those values. Fill out the  '*get_anchor_labels_and_offsets*' helper function below.

# %%
# You may use this helper function that computes the IoU of two boxes
def bb_intersection_over_union(boxA, boxB):

    # determine the (x, y)-coordinates of the intersection rectangle
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])

    # compute the area of intersection rectangle
    interArea = abs(max((xB - xA, 0)) * max((yB - yA), 0))
    if interArea == 0:
        return 0
    # compute the area of both the prediction and ground-truth
    # rectangles
    boxAArea = abs((boxA[2] - boxA[0]) * (boxA[3] - boxA[1]))
    boxBArea = abs((boxB[2] - boxB[0]) * (boxB[3] - boxB[1]))

    # compute the intersection over union by taking the intersection
    # area and dividing it by the sum of prediction + ground-truth
    # areas - the interesection area
    iou = interArea / float(boxAArea + boxBArea - interArea)

    # return the intersection over union value
    return iou

def permute_and_flatten(layer, N, A, C, H, W):
    # helper function that rearranges the input for the loss function
    layer = layer.view(N, -1, C, H, W)
    layer = layer.permute(0, 3, 4, 1, 2)
    layer = layer.reshape(N, -1, C)
    return layer

def reshape_regressions(cls_pred, box_pred):
    # helper function that gets outputs in the right shape for applying the loss
    # A = number of anchors (3)
    # C is 1
    N, AxC, H, W = cls_pred.shape
    Ax4 = box_pred.shape[1]
    A = Ax4 // 4
    C = AxC // A
    cls_pred = permute_and_flatten(cls_pred, N, A, C, H, W)
    
    box_pred = permute_and_flatten(box_pred, N, A, 4, H, W)
    return cls_pred, box_pred

def get_offsets1(gt_boxes, ex_boxes):
    """
    This function returns the offsets that need to applied to gt_boxes to morph them into ex_boxes.
    Both boxes should be of the same shape, N x 4.
    The output would be offsets given in a torch tensor of size N x 4.
    """
    ex_width = ex_boxes[2] - ex_boxes[0]
    ex_height = ex_boxes[3] - ex_boxes[1]
    ex_center_x = ex_boxes[0] + 0.5*ex_width
    ex_center_y = ex_boxes[1] + 0.5*ex_height

    gt_width = gt_boxes[2] - gt_boxes[0]
    gt_height = gt_boxes[3] - gt_boxes[1]
    gt_center_x = gt_boxes[0] + 0.5*gt_width
    gt_center_y = gt_boxes[1] + 0.5*gt_height


    delta_x = (gt_center_x - ex_center_x) / ex_width
    delta_y = (gt_center_y - ex_center_y) / ex_height
    delta_scaleX = torch.log(gt_width / ex_width)
    delta_scaleY = torch.log(gt_height / ex_height)

    offsets = torch.cat([delta_x.unsqueeze(0), 
                    delta_y.unsqueeze(0),
                    delta_scaleX.unsqueeze(0),
                    delta_scaleY.unsqueeze(0)],
                dim=0)
    return offsets

# This is the function you should complete      
def get_anchor_labels_and_offsets(true_boxes, anchor_boxes, sz=128):
    '''    
    INPUT:
    true_boxes: [Nx4]: actual bounding boxes in the image. Here N is the number of bounding boxes the image has.
    anchor_boxes: [192 x 4]: Anchor boxes of an image of size 128 x 128 with stride 16. 
    sz : 128
    OUTPUT: 
    anchor_classes: [192 x 1] : Class labels for each anchor: 1 is for foreground, 0 is for background and -1 is 
                            for a bad anchor [where IOU is between 0.3 and 0.7].
    anchor_offsets: [192 x 4]: Offsets for anchor to best fit the bounding box object. Assign 0 values for 0 and -1 class anchors.
    '''
    high_threshold = 0.7
    low_threshold = 0.3

    n_BBs = true_boxes.shape[0]
    n_anchors = anchor_boxes.shape[0]
    anchor_classes = torch.zeros((n_anchors,1))
    anchor_offsets = torch.zeros((n_anchors,4))
    
    for i in range(n_anchors):
      max = (0, 0)
      for j in range(n_BBs):
        iou = bb_intersection_over_union(anchor_boxes[i].cuda(), true_boxes[j])
        if iou > max[0]:
          max = (iou, j)
      # if iou is higher than the high threshold we'll class it as 1 (foreground)
      # else it will be 0 or -1 but maybe in other bounding boxes there will be an object
      # so we break only if we get a 1
      if max[0] > high_threshold:
        anchor_classes[i] = 1
        anchor_offsets[i] = get_offsets1(anchor_boxes[i], true_boxes[max[1]])
      elif max[0] < low_threshold:
        anchor_classes[i] = 0
      else:
        anchor_classes[i] = -1
    return anchor_classes, anchor_offsets


#  The main function - no need to modify
def get_GT_anchors(target, sample, anchor_boxes):
    '''
    Input
    target => Set of bounding boxes for each image.
    Sample => Each image
    Output:
    Bounding box offsets and class labels for each anchor.
    '''
    batched_preds = []
    batched_offsets = []
    final_anchor_labels = []
    final_anchor_offsets = []
    iter = 0
    for t, s in zip(target, sample):
        bboxes = t['bounding_box'].to(device).float()     
        anchor_labels, anchor_offsets = get_anchor_labels_and_offsets(bboxes, anchor_boxes, sz=128)

        final_anchor_labels.append(anchor_labels)
        final_anchor_offsets.append(anchor_offsets)

    final_anchor_labels = torch.squeeze(torch.stack(final_anchor_labels, dim=0))
    final_anchor_offsets = torch.stack(final_anchor_offsets, dim=0)
    return final_anchor_labels, final_anchor_offsets

# %% [markdown]
# ### Test code (for get_GT_anchors) that you might want to use

# %%
sample, target = iter(trainloader).next()
sample = torch.stack(sample,dim=0)

#assert len(anchor_offsets) == batch_sz
assert sample.shape == (batch_sz,3,128,128)
assert anchor_boxes.shape == (192,4)

anchor_labels, anchor_offsets = get_GT_anchors(target, sample, anchor_boxes)

assert anchor_labels.shape == (batch_sz,192)
assert anchor_offsets.shape == (batch_sz,192,4)

# %% [markdown]
# # **Supervision:** 2. defining loss functions
#
# We need to define loss functions which will compare the ground-truth-extracted data with the predictions of the network. We use a combination of two losses:
#
# 1. **Classification Loss** - The classification loss should be applied to all positive (containing an object) and negative anchors (does not contain an object). The loss should not be calculated for the anchors whose IOU values are between 0.7 and 0.3. Apply a binary-cross-entropy-loss (e.g. torch.nn.BCELoss) between the objecteness score and the network classification.
# 2. **Bounding-Box Update Loss** - The BB loss should be applied to all positive (containing an object) anchors. The loss should not be calculated for the anchors whose IOU values are below 0.7. Apply a Smooth L1 loss (e.g. torch.nn.SmoothL1Loss) to regress on the bounding box offsets.
#
# Note that in this setup the ratio between sampled background and foreground anchors might be biased towards over-sampling background anchors. This could be handled (**this is optional**) by implementing hard online negative sampling, which means to correct this bias.
#
# Your third ***task*** [**10%**] is to write the code for the '*class_loss*' and '*bbox_loss*' loss functions.

# %%
def class_loss(pred_class, anchor_labels, device="cuda"):
  total_loss = torch.zeros(1).cuda()
  for i in range(anchor_labels.shape[0]):
    for j in range(anchor_labels.shape[1]):
      if anchor_labels[i][j] != -1:
        BCELoss = torch.nn.BCELoss()
        curr_loss = BCELoss(pred_class[i][j], anchor_labels[i][j])
        total_loss += curr_loss
  return total_loss

def bbox_loss(out_bbox, anchor_offsets, anchor_labels):
  total_loss = torch.zeros(1).cuda()
  for i in range(anchor_labels.shape[0]):
    for j in range(anchor_labels.shape[1]):
      if anchor_labels[i][j] == 1:
        smooth = torch.nn.SmoothL1Loss()
        curr_loss = smooth(out_bbox[i][j].cuda(), anchor_offsets[i][j].cuda())
        total_loss += curr_loss
  return total_loss

# %% [markdown]
# ## Training Function.
#
# This is the training function. You do not need to change any code here, though you might want to add some debugging signals.

# %%
def train(ep, model, trainloader, optimizer):
        total_loss = 0
        b_loss = 0
        c_loss = 0
        debug_freq = 10
        validation_freq = 50
        window_loss = np.zeros(3)
        for i, (sample, targets) in enumerate(trainloader):

            ims = torch.stack(list(sample), dim=0).to(device)
            model.train() # switch to train mode

            anchor_labels, anchor_offsets = get_GT_anchors(targets, ims, anchor_boxes)
            pred_class, pred_bb = model(ims)      

            # print(anchor_offsets[0])
            # print(anchor_labels[0])
            loss_bbox = bbox_loss(pred_bb, anchor_offsets, anchor_labels)
            # print(loss_bbox)
            print('loss_bbox:',loss_bbox, 'loss_bbox.item()', loss_bbox.item(), 'type:', type(loss_bbox), 'shape:', loss_bbox.shape)    
            # print('min:',anchor_labels.min().min(),'max:',anchor_labels.max().max())
            loss_cls = class_loss(pred_class, anchor_labels.cuda())
            print('loss_cls:',loss_cls.item(), 'type:', type(loss_cls), 'shape:', loss_cls.shape)                    
            
            loss = loss_cls + loss_bbox 
            #print('>>>> cls loss shape', loss_cls.shape, 'box loss shape', loss_bbox.shape, )            

            # gradient step
            if loss.item() != 0:
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()


            # validation (once in a while)
            if i%validation_freq==(validation_freq-1):
                print('>> iteration',i+1,'out of',len(trainloader), ': VALIDATING on', len(valloader), 'batches...')
                model.eval() # switch to eval mode

                val_losses = np.zeros(len(valloader))
                for j, (sample, targets) in enumerate(valloader):
                    ims = torch.stack(list(sample), dim=0).to(device)

                    anchor_labels, anchor_offsets = get_GT_anchors(targets, ims, anchor_boxes)
                    pred_class, pred_bb = model(ims)               
                      
                    loss_bbox = bbox_loss(pred_bb, anchor_offsets, anchor_labels)
                    loss_cls = class_loss(pred_class, anchor_labels.cuda())
                    val_losses[j] = loss_cls + loss_bbox 
              
                # print('>> iteration',i+1,'out of',len(trainloader), ': VALIDATION loss:', val_losses.mean())

            # debugging
            total_loss += loss.item()
            window_loss = window_loss + np.array([loss_bbox.item(), loss_cls.item(), loss.item()])/debug_freq

            if i%debug_freq==(debug_freq-1):
              # print('>> iteration',i+1,'out of',len(trainloader), ': loss ', window_loss[2], '(closs', window_loss[0], 'bloss', window_loss[1], ')')
              window_loss = np.zeros(3)
        #print(total_loss)    
        avg_loss = float(total_loss / len(trainloader))
        print('Trained Epoch: {} | Avg Train Loss over epoch: {}'.format(ep, avg_loss))

# %% [markdown]
# # **Training** - model optimization and storing
# This cell contains the entire training (optimization) of your model. At the end, the resulting model is saved as a '.pt', which you are required to submit along with this main 'ipynb' file.
#
# ## **IMPORTANT NOTICE**:  When we run your submission we will run all of the notebook cells **except** this cell (further down there is a cell that loads the saved model)

# %%
from torch.optim.lr_scheduler import LambdaLR
n_epochs = 24
model = ShapesModel().to(device)

learning_rate = 1
exp = 0
optimizer = torch.optim.SGD(model.parameters(),lr=learning_rate, momentum=0.9, weight_decay=1e-4)    
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate*0.01)

# optimize

# Assuming optimizer has two groups.
lambda_group1 = lambda epoch: learning_rate / (2 ** exp)
scheduler = LambdaLR(optimizer, lr_lambda=[lambda_group1])


for ep in range(n_epochs):
    print('==================================== epoch', ep, '=====================================')
    train(ep, model, trainloader, optimizer)
    if (ep % 6 == 0 and ep != 0):
      exp += 1
      scheduler.step()
    



# Specify a path
PATH = "entire_model.pt"

# Save
torch.save(model, PATH)
# Out:
# Streaming output truncated to the last 5000 lines.
# loss_cls: 1.4671683311462402 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0197], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.01966499723494053 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.009067052975296974 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0408], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.04081204533576965 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.023586174473166466 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0163], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.016321204602718353 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.45663172006607056 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0162], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.01615174300968647 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.11173374205827713 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0138], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.013795137405395508 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.02752860076725483 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0140], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.014024442993104458 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 2.7750089168548584 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0196], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.019635861739516258 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.02441977709531784 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0454], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.04540758207440376 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 1.5712387561798096 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0336], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03356558084487915 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.016654372215270996 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0144], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.014372758567333221 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0020430218428373337 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0351], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.035073377192020416 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 2.8207714557647705 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0164], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.01637532375752926 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.011270172894001007 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0542], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.054192785173654556 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 1.513181209564209 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0459], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.04592856764793396 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.18617187440395355 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0385], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03845053166151047 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.021264294162392616 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0329], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.032926492393016815 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.019881457090377808 type: <class 'torch.Tensor'> shape: torch.Size([1])
# >> iteration 250 out of 300 : VALIDATING on 150 batches...
# loss_bbox: tensor([0.0087], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.008657311089336872 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.010713555850088596 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0163], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.016259921714663506 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.08681781589984894 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0494], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.04935777187347412 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 10.134206771850586 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0403], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.040252458304166794 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.054000865668058395 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0580], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.057950809597969055 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.007570899091660976 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0371], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03714529424905777 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 3.2041406631469727 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0138], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.013753045350313187 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 7.92252254486084 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0333], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.033335380256175995 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.15819679200649261 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0442], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.04422888532280922 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.05998820811510086 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0189], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.018897537142038345 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.10586482286453247 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0308], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.030781803652644157 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.12724627554416656 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0277], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.02774547040462494 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 5.907013416290283 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0198], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.01980268955230713 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 1.1323025226593018 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0147], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.014705929905176163 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.19380219280719757 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0471], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.047088176012039185 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.2516308128833771 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0356], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03563695028424263 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 1.2756872177124023 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0353], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03534037247300148 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.2848503887653351 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0165], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.01648380234837532 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.4052938222885132 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0317], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03167491778731346 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 5.4078240394592285 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0331], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03307552635669708 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.09741009026765823 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0248], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.024833139032125473 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.5952407717704773 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0464], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.046383678913116455 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.08402886986732483 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0501], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.050054386258125305 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 3.984699010848999 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0171], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.017140427604317665 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.045905403792858124 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0174], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.017372222617268562 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.02320554479956627 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0430], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.04299034923315048 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.18355612456798553 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0228], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.022815395146608353 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.414700448513031 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0402], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.04024900123476982 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.07718347012996674 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0239], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.023854777216911316 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0988474190235138 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0444], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.04442061856389046 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 2.6672346591949463 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0292], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.02918213978409767 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.10057320445775986 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0244], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.024424705654382706 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.1425497680902481 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0474], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.047357283532619476 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.023478243499994278 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0205], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.02053455449640751 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.15578056871891022 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0189], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.018878987058997154 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.026285894215106964 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0241], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.024139562621712685 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.8704307675361633 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0422], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.04219970852136612 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.6488043665885925 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0333], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.033252689987421036 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 5.223082542419434 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0245], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.024478815495967865 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 1.4832048416137695 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0156], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.01558876596391201 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.030989037826657295 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0419], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.0419137179851532 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.4057212173938751 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0373], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03725660219788551 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 3.7242963314056396 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0206], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.020586270838975906 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 1.532545566558838 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0156], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.015597570687532425 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 1.0298383235931396 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0210], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.020990274846553802 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 3.880418539047241 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0119], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.011895552277565002 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.13434503972530365 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0172], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.01717955246567726 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.22048230469226837 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0199], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.019894056022167206 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.5998654961585999 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0823], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.0823214203119278 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.5002492070198059 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0231], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.023147376254200935 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.6547990441322327 type: <class 'torch.Tensor'> shape: torch.Size([1])
# >> iteration 300 out of 300 : VALIDATING on 150 batches...
# Trained Epoch: 15 | Avg Train Loss over epoch: 0.8249359580564002
# ==================================== epoch 16 =====================================
# loss_bbox: tensor([0.0498], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.04978223890066147 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 1.384393572807312 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0160], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.016022277995944023 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.24841727316379547 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0275], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.027498118579387665 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.39856377243995667 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0180], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.017959708347916603 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.15733672678470612 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0107], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.010722190141677856 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.1952778548002243 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0777], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.07765349000692368 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.2419642060995102 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0374], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03741682693362236 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.3009428381919861 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0613], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.06130582094192505 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.08481009304523468 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0341], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03412257507443428 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.06843212246894836 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0298], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.02976367622613907 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0944717675447464 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0232], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.023211413994431496 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.15583457052707672 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0143], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.014253806322813034 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.4591078460216522 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0317], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03171473369002342 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.14521612226963043 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0403], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.040296927094459534 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.09783019125461578 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0097], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.009673673659563065 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.018995709717273712 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0334], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03337659686803818 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.3919237554073334 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0163], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.016279269009828568 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.031627774238586426 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0254], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.025404369458556175 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.03629275783896446 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0260], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.02596159093081951 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.13688190281391144 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0259], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.02589595317840576 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 2.871569871902466 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0546], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.054594483226537704 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.25628548860549927 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0301], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03009520098567009 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.1670859456062317 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0521], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.052089840173721313 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.15006595849990845 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0351], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.035076454281806946 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.3535696268081665 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0336], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03361271321773529 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.11221646517515182 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0317], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03165694698691368 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.05939706787467003 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0532], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.05320679768919945 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 1.3804523944854736 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0501], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.05011186748743057 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.018873266875743866 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0419], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.04185032099485397 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.07200167328119278 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0679], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.06792154908180237 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.005042717792093754 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0260], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.0259865615516901 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 4.954745292663574 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0387], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03865935653448105 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.011050941422581673 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0238], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.023754196241497993 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.1919165402650833 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0148], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.014788368716835976 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.011854179203510284 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0287], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.028719764202833176 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.13347190618515015 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0298], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.029809536412358284 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 1.6850260496139526 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0682], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.06824944168329239 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.19836845993995667 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0323], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03225940093398094 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.11586717516183853 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0277], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.027712134644389153 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.024627909064292908 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0345], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.0345451794564724 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.8673044443130493 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0303], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.030324574559926987 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0293000228703022 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0734], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.07337002456188202 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.09360948204994202 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0490], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.048989757895469666 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.21572084724903107 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0345], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.034547097980976105 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.183585062623024 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0235], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.023450380191206932 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.010515100322663784 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0124], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.012421964667737484 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.2129068523645401 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0571], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.05707791447639465 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 1.4527963399887085 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0259], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.02586868219077587 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.013619020581245422 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0372], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03720971941947937 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.027514435350894928 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0318], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.031782366335392 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.048415739089250565 type: <class 'torch.Tensor'> shape: torch.Size([1])
# >> iteration 50 out of 300 : VALIDATING on 150 batches...
# loss_bbox: tensor([0.0393], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.039263930171728134 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.020274939015507698 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0158], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.01576947793364525 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.26446041464805603 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0141], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.01414672750979662 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.01658877544105053 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0237], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.023665092885494232 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.18595372140407562 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0120], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.012005902826786041 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.041808661073446274 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0063], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.006251531653106213 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.02035050466656685 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0185], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.018460268154740334 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.02856399491429329 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0309], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.030906040221452713 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.15289252996444702 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0207], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.020737148821353912 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.03238415718078613 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0211], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.0211248267441988 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.024070193991065025 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0350], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.034976527094841 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.1533467322587967 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0161], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.016111809760332108 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 6.1848955154418945 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0198], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.019761618226766586 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.10160285234451294 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0072], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.007154230959713459 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.45028167963027954 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0522], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.05222819745540619 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.12379731237888336 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0237], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.02371482364833355 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0345606729388237 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0157], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.015671171247959137 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.06825413554906845 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0239], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.02391550876200199 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.07765437662601471 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0339], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03389636054635048 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.21974502503871918 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0360], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.035964105278253555 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.4710540771484375 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0250], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.025045892223715782 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 1.9784125089645386 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0404], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.04038991779088974 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.17280393838882446 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0116], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.011586219072341919 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.03151209279894829 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0103], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.010304643772542477 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.03188523277640343 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0072], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.007166337221860886 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.15865963697433472 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0257], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.025672532618045807 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.016340842470526695 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0274], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.027356594800949097 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.022596146911382675 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0331], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03312423452734947 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.018971549347043037 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0403], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.04031302407383919 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.013494085520505905 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0289], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.028942517936229706 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 1.351138710975647 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0141], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.014070765115320683 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.012972378171980381 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0036], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.003632090985774994 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.03138174116611481 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0363], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03628798574209213 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.11082006990909576 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0245], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.02448875643312931 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.28808507323265076 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0170], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.017049655318260193 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.025468021631240845 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0094], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.009402399882674217 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.008116302080452442 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0717], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.07166025042533875 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.23020264506340027 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0190], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.01903216913342476 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.007181033957749605 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0125], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.012474756687879562 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.06743655353784561 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0325], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03246968984603882 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.04900176823139191 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0253], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.02533814311027527 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.012963163666427135 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0355], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03549385815858841 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.06332459300756454 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0231], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.023061368614435196 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.4377708435058594 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0123], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.012251162901520729 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.014299556612968445 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0159], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.015898985788226128 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.22775906324386597 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0282], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.028186341747641563 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.09688408672809601 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0087], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.008671917952597141 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.1664443165063858 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0344], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03440683335065842 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 1.5392500162124634 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0303], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.030280007049441338 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0478895828127861 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0599], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.05994078889489174 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.19294843077659607 type: <class 'torch.Tensor'> shape: torch.Size([1])
# >> iteration 100 out of 300 : VALIDATING on 150 batches...
# loss_bbox: tensor([0.0317], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03166491910815239 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 1.1147959232330322 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0305], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.030506368726491928 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0110826026648283 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0158], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.0157505851238966 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.06311521679162979 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0529], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.05293557792901993 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.06805036962032318 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0273], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.027333807200193405 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.03115152381360531 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0794], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.07938949018716812 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.4761904180049896 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0287], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.02874939516186714 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.09716775268316269 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0179], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.017906205728650093 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0032578296959400177 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0240], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.024014821276068687 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.08787215501070023 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0293], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.029333561658859253 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.09084109961986542 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0663], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.06630872935056686 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 1.2846310138702393 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0471], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.04707327485084534 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.007442843168973923 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0248], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.024788321927189827 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.3206157386302948 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0340], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03399810194969177 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.016196735203266144 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0465], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.04653005301952362 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.23146429657936096 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0224], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.022411033511161804 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.11105117946863174 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0086], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.008619755506515503 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.4482215940952301 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0308], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03084082156419754 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.8613907694816589 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0436], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.043616052716970444 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.9448203444480896 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0404], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.04040638357400894 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.4391075074672699 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0375], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03746233135461807 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.028470467776060104 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0232], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.02319660596549511 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.014643209055066109 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0242], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.024206455796957016 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.024436991661787033 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0375], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03752082586288452 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.05262480303645134 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0356], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03555964305996895 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.009060610085725784 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0655], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.06554612517356873 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.028477896004915237 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0233], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.023268867284059525 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.1418324112892151 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0164], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.01641913689672947 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.26060813665390015 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0159], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.015871120616793633 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.01452957559376955 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0199], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.01991470530629158 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.21719445288181305 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0836], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.08362209051847458 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.04277706891298294 type: <class 'torch.Tensor'> shape: torch.Size([1])
# ...
# loss_cls: 0.3903702199459076 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0259], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.02585340477526188 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0011876767966896296 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0282], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.028184061869978905 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0022391180973500013 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0233], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.023305563256144524 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0008313052821904421 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0374], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03741246461868286 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0023184220772236586 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0378], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03776447847485542 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.00975455716252327 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0217], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.02168581448495388 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.010096116922795773 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0364], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03638361394405365 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0006298770313151181 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0399], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03987593203783035 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0009825951419770718 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0164], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.01643959991633892 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0037605164106935263 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0209], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.020906461402773857 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.010980986058712006 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0143], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.01426403596997261 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.03337671980261803 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0183], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.018254369497299194 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0013959617353975773 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0252], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.02517952211201191 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 3.969676254200749e-05 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0367], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.0366850271821022 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.03432890400290489 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0028], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.002834571059793234 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.012000873684883118 type: <class 'torch.Tensor'> shape: torch.Size([1])
# >> iteration 250 out of 300 : VALIDATING on 150 batches...
# loss_bbox: tensor([0.0248], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.024773716926574707 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0006655893521383405 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0152], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.01519870012998581 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0002468866005074233 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0187], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.01870478317141533 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0010598860681056976 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0197], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.019721321761608124 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.008762159384787083 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0325], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03245082497596741 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.11966726183891296 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0252], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.025208057835698128 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0014171262737363577 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0292], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.029248856008052826 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.15997014939785004 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0172], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.01718156412243843 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.00013887975364923477 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0225], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.022530999034643173 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.02684115804731846 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0375], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03754569962620735 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0003683122340589762 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0181], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.018053565174341202 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.004400873091071844 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0235], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.0235233623534441 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.00995921902358532 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0204], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.020379651337862015 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.05240193381905556 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0394], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.039375633001327515 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.02416897937655449 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0321], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.032136909663677216 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.007424217648804188 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0253], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.025329219177365303 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.004724498372524977 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0219], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.021855371072888374 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.009122162126004696 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0126], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.012621544301509857 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.00047276183613575995 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0237], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.023681718856096268 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0003076883149333298 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0160], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.015990667045116425 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0011048432206735015 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0108], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.010792331770062447 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.002975204959511757 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0321], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03208303824067116 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.007636175490915775 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0196], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.01957467943429947 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.00012135703582316637 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0312], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03123459778726101 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0005709980614483356 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0143], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.01425258256494999 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.002410839544609189 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0468], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.04679304361343384 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.011244390159845352 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0207], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.020740369334816933 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0004978074575774372 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0173], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.017326680943369865 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0041175344958901405 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0105], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.010491684079170227 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.00018310688028577715 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0309], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.030885476619005203 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.027196548879146576 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0192], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.019244622439146042 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0008191306842491031 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0138], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.013847675174474716 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0007032331195659935 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0354], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03541269153356552 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0002159508876502514 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0299], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.029872098937630653 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.011700406670570374 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0296], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.029608292505145073 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0011349355336278677 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0184], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.018389809876680374 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.00512573029845953 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0220], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.022038031369447708 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.005329577252268791 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0307], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03071810118854046 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.35122421383857727 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0282], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.0282046590000391 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0030360189266502857 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0167], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.016665121540427208 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0015961062163114548 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0193], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.019293684512376785 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.001616645255126059 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0270], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.0269637331366539 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0026546695735305548 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0355], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.03552984818816185 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.001093148603104055 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0115], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.011487173847854137 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0001037724141497165 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0070], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.007023407146334648 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.006205297075212002 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0192], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.01917729526758194 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.00036425815778784454 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0156], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.01557197142392397 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0015724272234365344 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0254], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.025391459465026855 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0024170763790607452 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0238], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.02381286956369877 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.00013160789967514575 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_bbox: tensor([0.0098], device='cuda:0', grad_fn=<AddBackward0>) loss_bbox.item() 0.009796805679798126 type: <class 'torch.Tensor'> shape: torch.Size([1])
# loss_cls: 0.0019149500876665115 type: <class 'torch.Tensor'> shape: torch.Size([1])
# >> iteration 300 out of 300 : VALIDATING on 150 batches...
# Trained Epoch: 23 | Avg Train Loss over epoch: 0.06373133248882368

# %% [markdown]
# # Model Predictions - (including post-processing)
#
# At this point, you may apply your model on input images and get output results (in the form of a score and a shift BB for each of the anchors). This result would require some post-processing, in order to come up with a presentable and measurable result.
#
# The '*predict*' function is designed to output max_BBs = 5 leading bounding boxes. In order to do so, it relies on the anchor scores of your output and applies non-maximal-suppression (NMS) as a main way to clear up the output.
#
# NMS is required since many of the anchors near an actual object will fire, resulting in a lot of boxes. NMS handles these multiple predictions by 'choosing' a single box for a predicted object instead of multiple ones. This is best signified through another image:
#
# ![NMS](https://miro.medium.com/max/1000/0*WI5_K3bAbYaRyzE-.png)

# %%
# apply model and post-processing
def predict(model, sample, max_BBs=5):

    # Apply model:
    ims = torch.stack(list(sample), dim=0).to(device)
    pred_class, pred_bb = model(ims)    

    # Post processing:
    iou_threshold = 0.1 # you may manipulate this. 

    target = [{} for i in range(batch_sz)]

    boxes = torch.zeros([192,4]).cuda()
    for ind in range(batch_sz):
        for t in range(192):
            try:
              boxes[t] =  torch.tensor(anchor_boxes[t]).cuda() + pred_bb[ind,t]
              scores = pred_class[ind].squeeze()
              nms_indices = nms(boxes, scores, iou_threshold) # NMS
            except:
              pass
        if len(nms_indices) > max_BBs:
            nms_indices = nms_indices[:max_BBs]
        # print(target[ind]['bounding_box'])
        # print(nms_indices)
        # print(boxes[nms_indices])
        target[ind]['bounding_box'] = boxes[nms_indices]

    return target

# %%
# Testing the 'predict' function on a train or validation batch

# taking a batch (you may change trainloader to valloader)
sample, target = iter(trainloader).next()
sample = torch.stack(sample,dim=0)

max_BBs = 5 # do not modify this

# predict
result = predict(model, sample, max_BBs=max_BBs)

# batch accuracies function - Do not modify!
def get_batch_accuracies(result, target, max_BBs=5):
    accuracies = np.zeros(batch_sz)
    for i in range(batch_sz):
        res_BBs = result[i]['bounding_box'].cpu()
        if res_BBs.shape[0] > max_BBs:
            res_BBs = res_BBs[:max_BBs]
        res = box_iou(res_BBs,target[i]['bounding_box'])
        best_preds = res.max(0).values
        accuracies[i] = ((best_preds>0.5).count_nonzero()/len(best_preds))
    return accuracies

# check accuracy:
accuracies = get_batch_accuracies(result,target)
print('accuracies:', accuracies)
print('mean accuracy:', accuracies.mean())

# visualize:
visDet(sample, result)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# accuracies: [1.         1.         1.         0.66666669]
# mean accuracy: 0.9166666716337204

# %% [markdown]
# # Load model and evaluate on the test set
#
# Your fourth and last ***task*** [**30%**] is to tune your network in order to get better accuracy. You may play with the data (e.g. amounts of), model, it's training (e.g. hyper parameters), post-processing, etc'.
#
# Please describe here shortly what you did in order to get your best results:
#
# * **Increased the** **number of layers**  of the model from 18 layers to 34. As we put more layers into the ResNet architucture, there are more parameters for computation, which increase the accuracy significantly
#
# * **Increased the sizes of the train dataset and validation dataset**. We've done so because the more samples the network is familiar with, the more trained and accurate the network is. The bigger training set size means that the model's parameters are more accurate, and the bigger validation set size means that the hyper-parameters are more accurate.
#
# * **Increased the number of epochs to 24**. The more epochs, the network is more trained.
#
# * Implemented **step decay** for a dynamic learning rate. We declared that the training process will due to 24 epochs, with initial learning rate of 0.1. We defined that every 6 epochs the learning rate will be halved. We've done it because we noticed that after 6 epochs the training of the network is locally converging. It means that the optimizer knows where is the local minimum direction from the SGD, but the learning rate is too high and the optimizer can't reach there, hence the loss value remains the same. So we decrease the learning rate to help the network to get the local minimum, so it will have minimum loss.

# %%
# Load
if True:
    model = torch.load(PATH)
    model.eval()

# %% [markdown]
# ### accuracy functions - do not modify

# %%
# batch accuracies function - Do not modify!
def get_batch_accuracies(result, target, max_BBs=5):
    accuracies = np.zeros(batch_sz)
    for i in range(batch_sz):
      try:
        res_BBs = result[i]['bounding_box'].cpu()
        if res_BBs.shape[0] > max_BBs:
            res_BBs = res_BBs[:max_BBs]
        res = box_iou(res_BBs,target[i]['bounding_box'])
        best_preds = res.max(0).values
        accuracies[i] = ((best_preds>0.5).count_nonzero()/len(best_preds))
      except:
        pass
    return accuracies

# accuracies function - Do not modify!
def evaluate_accuracy(loader):
    accuracy = 0
    for j, (sample, target) in enumerate(loader):
          sample = torch.stack(list(sample), dim=0).to(device)
          result = predict(model, sample)
          batch_accuracies = get_batch_accuracies(result,target)
          accuracy += batch_accuracies.mean()
    result = accuracy/(j+1)
    # print('mean accuracy:', result)
    return result

# %% [markdown]
# ## accuracy evaluations (test set is the important one..)

# %%
_, _, testloader = get_shapes_loader(batch_sz=batch_sz, test_samples=500)

train_acc = evaluate_accuracy(trainloader)
val_acc = evaluate_accuracy(valloader)
test_acc = evaluate_accuracy(testloader)
print('train acc:',train_acc)
print('val acc:',val_acc)
print('test acc:',test_acc)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# train acc: 0.8740277801454067
# val acc: 0.8806944468617439
# test acc: 0.886833335518837
